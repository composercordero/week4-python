# %%
# https://www.youtube.com/watch?v=T_7vhsSBi7c&t=1s

class ROI_calc():
    pass

# total_monthly_income
# total_monthly_expenses
# total_monthly_
# total_investment
# annual_cash_flow

# def income():

    # Rental Income = 2000
    # Laundry Income = 50
    # Storage Income = 50
    # Miscellaneous Income = 50
    
    # total_monthly_income = 2150

# def expenses():

    # Tax = 150
    # Insurance = 100
    # Utilities = 0
        # Electric
        # Water
        # Garbage
        # Gas
    # HOA = 0
    # Lawn care = 0
    # Snow care = 0
    # Vacancy = 100
    # Repairs = 100
    # CapEx - Capital Expenditure (Replacing things) = 100
    # Property Management = 200
    # Mortgage = 860
    
    # total_monthly_expenses = 1610
    
# The zeros in utilities and lawn/snow care means that the tenants will take care of it.
# create a flag that asks if the tenants are paying these things and if on, ask the questions.

# def cash_flow(): - How much extra money do I have monthly

    # total_monthly_cash_flow = self.total_monthly_income - self.total_monthly_expenses
    
    # 390

# def investment():
    
    # Down Payment = 40000
    # Closing Costs = 3000
    # Rehab Budget = 7000
    # Miscellaneous = 0
    
    # total_investment = 50000
    
# calculate_roi():    
    
    # annual_cash_flow = total_monthly_cash_flow * 12
    
    # annual_cash_flow / total_investment = self.roi (cash_on_cash_roi)
    
    # 4680 / 50000 = 9.36

def main():
    pass

# main()

# %%
# printing number with comma, 2 decimals, and dollar sign

num = 4680

print(f"${num:,.2f}")

# %%
# Questions format and validation
# All questions should contain int except for those that are yes or no

question = (input('What is your monthly ___? '))
while not question.strip().isnumeric():
    question = input('Please, input a valid number for your monthly ___ ')

# %%
# Questions format and validation
# All questions should contain int except for those that are yes or no

import re

def question(field):
    question = (input('What is your monthly {field}? '))
    while not re.match('^[\d]*$', question):
        question = input('Please, input a valid number for your monthly {field}: ')

# %%
import re

class roi_calc():
    
    def __init__(self):
        self.name = ''
        self.program = 'off'
        self.utilities = 'off'
        self.lawn = 'off'
        self.snow = 'off'
        self.prop = ''
        self.list_of_properties = []
    
    def __str__(self):
        return self.name.title()
    
    def __repr__(self):
        return f'< Roi | {self} >'

    def welcome(self):
        print ("""
        --------------------------------------------------------
                 That Annoying Wine Real State Agency
        --------------------------------------------------------
        """)
        name = input('What is your name? ')
        self.name = name
        print(f'\nHi, {self}! I hope you had a great time at our shop, and casino!\
        \n\nNow, let\'s see your ROI on that property you want to buy.\n')
        print('-'*60)
        address = input('What is the address of the property you would like to buy? ')
        prop = Property(address)
        print('-'*60)
        self.program = 'off'
        print(prop.electric)
        
    def income(self):
            
        prop.rental_income = question('rental income')
        prop.laundry_income = question('laundry income')
        prop.storage_income = question('storage income')
        prop.miscellaneous_income = question('miscellaneous income')

        prop.total_monthly_income = int(prop.rental_income) + int(prop.laundry_income) + \
        int(prop.storage_income) + int(prop.miscellaneous_income)
        
        print('-'*60)
        print(f'\nTotal income: ${prop.total_monthly_income:,.2f}')
        print('-'*60)
        
        return prop.total_monthly_income
        
    def expenses(self):

        lawn = input('Are you paying for lawn care? y/n ')
        while lawn not in {'y', 'n'}:
            lawn = input('Select a valid option. y/n ')
        if lawn == 'y':
            self.lawn = 'on'
        
        snow = input('Are you paying for snow care? y/n ')
        while snow not in {'y', 'n'}:
            snow = input('Select a valid option. y/n ')
        if snow == 'y':
                self.snow = 'on'
        
        utilities = input('Are you paying for utilities? y/n ')
        while utilities not in {'y', 'n'}:
            utilities = input('Select a valid option. y/n ')
        if utilities == 'y':
            self.utilities = 'on' 
        
        prop.tax = question('tax')
        prop.insurance = question('insurance')
        if self.utilities == 'on':
            prop.electric = question('electric bill')
            prop.water = question('water bill')
            prop.garbage = question('garbage bill')
            prop.gas = question('gas bill')
        
        if self.lawn == 'on':
            prop.lawn_care = question('lawn care')
        if self.utilities == 'on':
            prop.snow_care = question('snow care')
            
        prop.hoa = question('hoa')
        prop.vacancy = question('vacancy')
        prop.capex = question('capex')
        prop.property_management = question('property_management')
        prop.mortgage = question('mortgage')

        prop.total_monthly_expenses = int(prop.tax) + int(prop.insurance) + int(prop.electric)\
        + int(prop.water) + int(prop.garbage) + int(prop.gas) + int(prop.hoa) + int(prop.lawn_care)\
        + int(prop.snow_care) + int(prop.vacancy) + int(prop.capex) + \
        int(prop.property_management) + int(prop.mortgage)

        print('-'*60)
        print(f'\nTotal expenses: ${prop.total_monthly_expenses:,.2f}')
        print('-'*60)
        
        return prop.total_monthly_expenses

    def investment(self):
        prop.down_payment = question('down_payment')
        prop.closing_costs = question('closing_costs')
        prop.rehab_budget = question('rehab_budget')
        prop.miscellaneous = question('miscellaneous')

        prop.total_investment = int(prop.down_payment) + int(prop.closing_costs)\
        + int(prop.rehab_budget) + int(prop.miscellaneous)
        
        print(f'\nTotal investment: ${prop.total_investment:,.2f}')
        return prop.total_investment

    
    def cash_flow(self):
        prop.total_monthly_cash_flow = prop.total_monthly_income - prop.total_monthly_expenses
        return prop.total_monthly_cash_flow
    
    def calculate_roi(self):    
        
        prop.annual_cash_flow = prop.total_monthly_cash_flow * 12
        
        print('-'*60)
        print(f'Annual Cash Flow: {prop.annual_cash_flow:,.2f}')
        
        prop.roi = prop.annual_cash_flow / prop.total_investment
        print('-'*60)
        print(f'ROI: {prop.roi:,.2f}%')
        print('-'*60)
        
        return prop.roi
    
    def view_form(self):
        pass

    def question(field):
        question = (input('What is your monthly {field}? '))
        while not re.match('^[\d]*$', question):
            question = input('Please, input a valid number for your monthly {field}: ')

class Property():
        
    def __init__(self, address):
        self.address = address
        self.total_monthly_income = 0
        self.total_monthly_expenses = 0
        self.total_investment = 0
        self.total_monthly_cash_flow = 0
        self.annual_cash_flow = 0
        self.roi = 0
        
        self.tax = 0
        self.Insurance = 0
        self.utilities_total = 0
        self.electric = 0
        self.water = 0
        self.sewage = 0
        self.garbage = 0
        self.gas = 0
        self.hoa = 0
        self.lawn_care = 0
        self.snow_care = 0
        self.vacancy = 0
        self.repairs = 0
        self.capex = 0
        self.property_management = 0
        self.mortgage = 0
        
    def __str__(self):
        return f'{self.address}'
    
    def __repr__(self):
        return f'< Property | {self} >'
        
def main():
    roi = roi_calc()
    roi.welcome()
    roi.program = 'on'
    
    while roi.program == 'on':
        user_action = input('What would you like to do?\n\
        1. Calculate ROI\n\
        2. Edit Previous\n\
        3. View Previous\n\
        4. Exit ').lower()

        if user_action in '1 calculate roi':
            roi.income()
            roi.expenses()
            roi.cash_flow()
            roi.investment()
            roi.calculate_roi()
        elif user_action in '2 Edit Previous':
            pass
        elif user_action in '3 View Form':
            roi.view_form()
        elif user_action in '4 exit':
            program = 'off'
            break

main()

# Missing validation of expenses questions
# Missing Edit -> question, recall of the function selected
# missing view which is the view function
# Out:
#         --------------------------------------------------------
#                  That Annoying Wine Real State Agency
#         --------------------------------------------------------
#
# What is your name? Carlos
#
# Hi, Carlos! I hope you had a great time at our shop, and casino!
#
# Now, let's see your ROI on that property you want to buy.
#
# ------------------------------------------------------------
# What is the address of the property you would like to buy? 1808 Los Olivios Way
# ------------------------------------------------------------
# 0
# What would you like to do?
#         1. Calculate ROI
#         2. Edit Previous
#         3. View Previous
#         4. Exit 1
# What is your monthly rental income? 200
# What is your monthly laundry income? 200
# What is your monthly storage income? 200
# What is your monthly miscellaneous income? 200
# ------------------------------------------------------------
#
# Total income: $800.00
# ...
