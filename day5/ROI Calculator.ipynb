# %%
# https://www.youtube.com/watch?v=T_7vhsSBi7c&t=1s

class ROI_calc():
    pass

# total_monthly_income
# total_monthly_expenses
# total_monthly_
# total_investment
# annual_cash_flow

# def income():

    # Rental Income = 2000
    # Laundry Income = 50
    # Storage Income = 50
    # Miscellaneous Income = 50
    
    # total_monthly_income = 2150

# def expenses():

    # Tax = 150
    # Insurance = 100
    # Utilities = 0
        # Electric
        # Water
        # Seware
        # Garbage
        # Gas
    # HOA = 0
    # Lawn care = 0
    # Snow care = 0
    # Vacancy = 100
    # Repairs = 100
    # CapEx - Capital Expenditure (Replacing things) = 100
    # Property Management = 200
    # Mortgage = 860
    
    # total_monthly_expenses = 1610
    
# The zeros in utilities and lawn/snow care means that the tenants will take care of it.
# create a flag that asks if the tenants are paying these things and if on, ask the questions.

# def cash_flow(): - How much extra money do I have monthly

    # total_monthly_cash_flow = self.total_monthly_income - self.total_monthly_expenses
    
    # 390

# def investment():
    
    # Down Payment = 40000
    # Closing Costs = 3000
    # Rehab Budget = 7000
    # Miscellaneous = 0
    
    # total_investment = 50000
    
# calculate_roi():    
    
    # annual_cash_flow = total_monthly_cash_flow * 12
    
    # annual_cash_flow / total_investment = self.roi (cash_on_cash_roi)
    
    # 4680 / 50000 = 9.36

def main():
    pass

# main()

# %%
# printing number with comma, 2 decimals, and dollar sign

num = 4680

print(f"${num:,.2f}")

# %%
# Questions format and validation
# All questions should contain int except for those that are yes or no

question = (input('What is your monthly ___? '))
while not question.strip().isnumeric():
    question = input('Please, input a valid number for your monthly ___ ')

# %%
# Questions format and validation
# All questions should contain int except for those that are yes or no

import re

def question(field):
question = (input('What is your monthly {field}? '))
while not re.match('^[\d]*$', question):
    question = input('Please, input a valid number for your monthly {field}: ')

# %%
class roi():
    
    def __init__(self):
        self.total_monthly_income = 0
        self.total_monthly_expenses = 0
        self.total_monthly = 0
        self.total_investment = 0
        self.annual_cash_flow = 0
        self.name = ''
        self.utilities = 'off'
        self.lawn = 'off'
        self.snow = 'off'
    
    def __str__(self):
        return self.name.title()
    
    def __repr__(self):
        return f'< Client | {self} >'

    def welcome(self):
        print ("""
        --------------------------------------------------------
                 That Annoying Wine Real State Agency
        --------------------------------------------------------
        """)
        name = input('What is your name? ')
        self.name = name
        print(f'\nHi, {self}! I hope you had a great time at our shop, and casino!\
        \n\nNow, let\'s see your ROI on that property you want to buy.')

    def income(self):

        self.rental_income = question('rental income')
        self.laundry_income = question('laundry income')
        self.storage_income = question('storage income')
        self.miscellaneous_income = question('miscellaneous income')

        total_income = int(self.rental_income) + int(self.laundry_income) + int(self.storage_income) + int(self.miscellaneous_income)
        self.total_income = int(total_income)
        print(f'\nYour total income: ${self.total_income:,.2f}')

def main():

    roi = roi()
    roi.welcome()
    
    program = 'on'

    while program = 'on':
        user_action = input('What would you like to do?\
        1. Calculate ROI\n\
        2. Edit Previous\n\
        3. View Previous\n\
        4. Exit\n').lower()

        if user_action in {'1 calculate roi'}:
            pass
        elif user_action in {'2 Edit Previous'}:
            pass
        elif user_action in {'3 View Previous'}:
            pass
        elif user_action in {'4 exit'}:
            program = 'off'
# Out:
# What is your monthly rental income? 2000
# What is your monthly laundry income? 200
# What is your monthly storage income? 200
# What is your monthly miscellaneous income? 200
# Your total income: $2,600.00

# %%
# Out:
# True
